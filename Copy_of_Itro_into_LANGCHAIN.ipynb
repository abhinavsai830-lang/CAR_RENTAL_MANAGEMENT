# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavsai830-lang/CAR_RENTAL_MANAGEMENT/blob/main/Copy_of_Itro_into_LANGCHAIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-google-genai
# !!pip install -U langchain-groq
# Out:
# ...
# ['Collecting langchain-groq',
#  '  Downloading langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)',
#  'Collecting groq<1.0.0,>=0.30.0 (from langchain-groq)',
#  '  Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)',
#  'Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (1.4.7)',
#  'Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.13.0)',
#  'Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)',
#  'Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)',
#  'Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.3)',
# ...

# %%
from google.colab import userdata
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage,SystemMessage

# %%
groq_key=userdata.get('GROQ_API_KEY')
gemini_key=userdata.get('GOOGLE_API_KEY')

# %%
system_message=SystemMessage(
    "You are a helpfull assisstent."
)
humen_message=HumanMessage(
    "role of RAG in Generative AI"
)
messages=[system_message,humen_message]

# %%
model=init_chat_model(
    "groq:llama-3.3-70b-versatile",
    api_key=groq_key
)

# %%
response=model.invoke(messages)
print(response)
# Out:
# content="RAG (Retrieval-Augmented Generation) is a technique used in generative AI models to improve their performance and efficiency. The role of RAG in generative AI is to enhance the model's ability to generate high-quality text by leveraging external knowledge sources.\n\n**What is RAG?**\n\nRAG is a framework that combines the strengths of two approaches:\n\n1. **Retrieval-based models**: These models use a database or knowledge graph to retrieve relevant information and generate text based on that information.\n2. **Generation-based models**: These models use neural networks to generate text from scratch, without relying on external knowledge sources.\n\n**How does RAG work?**\n\nThe RAG framework consists of three main components:\n\n1. **Retriever**: This component is responsible for retrieving relevant information from a database or knowledge graph. The retriever uses a query (e.g., a prompt or a question) to search for relevant information.\n2. **Generator**: This component
# ...

# %%
print(response.content)
# Out:
# RAG (Retrieval-Augmented Generation) is a technique used in generative AI models to improve their performance and efficiency. The role of RAG in generative AI is to enhance the model's ability to generate high-quality text by leveraging external knowledge sources.
#
# **What is RAG?**
#
# RAG is a framework that combines the strengths of two approaches:
#
# 1. **Retrieval-based models**: These models use a database or knowledge graph to retrieve relevant information and generate text based on that information.
# 2. **Generation-based models**: These models use neural networks to generate text from scratch, without relying on external knowledge sources.
#
# **How does RAG work?**
#
# The RAG framework consists of three main components:
#
# 1. **Retriever**: This component is responsible for retrieving relevant information from a database or knowledge graph. The retriever uses a query (e.g., a prompt or a question) to search for relevant information.
# ...
